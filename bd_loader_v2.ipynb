# %%
import fastf1
import fastf1.plotting
import pandas as pd 
import numpy as np

SEASON = 2025
ROUND = 1
SESSION = "R"

current_session = fastf1.get_session(2025, 1, 5)
current_session.load()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (31.06 GB) /home/kurios/.cache/fastf1
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core        WARNING 	Driver 4 completed the race distance 00:00.022000 before the recorded end of the session.
# ...

# %%
for driver_abbr in fastf1.plotting.list_driver_abbreviations(current_session):
    if driver_abbr 
        try:
            driver = db.query(Driver).filter(Driver.driver_abbreviation == driver_abbr).first()
            if not driver:
                driver = Driver(
                    driver_number = info[0],
                    driver_abbreviation = info[1],
                    driver_name = info[2],
                    driver_color = info[3],
                    country = info[4],
                )
                db.add(driver)
                db.flush()
# Out:
# VER
# LAW
# GAS
# DOO
# ANT
# RUS
# ALO
# STR
# LEC
# HAM
# TSU
# HAD
# ALB
# SAI
# HUL
# BOR
# OCO
# BEA
# NOR
# PIA

# %%
import sqlalchemy as sa

engine = sa.create_engine("postgresql+psycopg2://creator:roadtose@localhost:5432/f1_data", echo=True)

metadata = sa.MetaData()

metadata.reflect(bind=engine)
# Out:
# 2025-08-29 22:45:51,214 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-08-29 22:45:51,215 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-29 22:45:51,217 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-08-29 22:45:51,218 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-29 22:45:51,219 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-08-29 22:45:51,220 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-29 22:45:51,226 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-29 22:45:51,226 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# ...

# %%
CarData = metadata.tables['car_data']
CarData
# Out:
# Table('car_data', MetaData(), Column('brake', BOOLEAN(), table=<car_data>), Column('car_data_id', INTEGER(), table=<car_data>, primary_key=True, nullable=False, server_default=Identity(start=1, increment=1, minvalue=1, maxvalue=2147483647, cycle=False, cache=1)), Column('differential_distance', REAL(), table=<car_data>), Column('distance', REAL(), table=<car_data>), Column('distance_driver_ahead', INTEGER(), table=<car_data>), Column('drs_id', INTEGER(), ForeignKey('drs.drs_id'), table=<car_data>), Column('lap_id', INTEGER(), ForeignKey('lap.lap_id'), table=<car_data>), Column('n_gear', SMALLINT(), table=<car_data>), Column('relative_distance', REAL(), table=<car_data>), Column('rpm', SMALLINT(), table=<car_data>), Column('session_time', INTEGER(), table=<car_data>), Column('speed', SMALLINT(), table=<car_data>), Column('throttle', SMALLINT(), table=<car_data>), Column('time', INTEGER(), table=<car_data>), Column('track_status_id', INTEGER(), ForeignKey('track_status.track_status_id'
# ...

# %%
current_session = fastf1.get_session(2025, 1, 5)
current_session.load()
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core        WARNING 	Driver 4 completed the race distance 00:00.022000 before the recorded end of the session.
# ...

# %%
event_round_event_date = pd.to_datetime(current_session.event.EventDate).to_pydatetime()
event_round_event_date.year
# Out:
# 2025

# %%
current_session.laps.pick_drivers(4).get_pos_data()
# Out:
#                          Date   Status       X       Y     Z Source  \
# 0     2025-03-16 04:18:23.168  OnTrack -1046.0 -1476.0  86.0    pos
# 1     2025-03-16 04:18:23.548  OnTrack -1046.0 -1476.0  86.0    pos
# 2     2025-03-16 04:18:23.748  OnTrack -1051.0 -1471.0  86.0    pos
# 3     2025-03-16 04:18:24.148  OnTrack -1060.0 -1463.0  86.0    pos
# 4     2025-03-16 04:18:24.308  OnTrack -1066.0 -1457.0  86.0    pos
# ...                       ...      ...     ...     ...   ...    ...
# 23346 2025-03-16 06:00:28.407  OnTrack  -543.0 -1953.0  89.0    pos
# 23347 2025-03-16 06:00:28.567  OnTrack  -635.0 -1866.0  88.0    pos
# 23348 2025-03-16 06:00:28.807  OnTrack  -831.0 -1680.0  87.0    pos
# 23349 2025-03-16 06:00:29.167  OnTrack  -973.0 -1545.0  86.0    pos
# 23350 2025-03-16 06:00:29.328  OnTrack -1080.0 -1443.0  85.0    pos
#
#                         Time            SessionTime
# 0     0 days 00:00:00.194000 0 days 01:11:00.549000
# ...

# %%
def get_wind_direction_cat(WindDirection):
    normalized_direction = WindDirection % 360
    if normalized_direction < 0:
        normalized_direction += 360
    match normalized_direction:
        case _ if (normalized_direction >= 348.75 or normalized_direction < 11.25):
            return 1
        case _ if (normalized_direction >= 11.25 and normalized_direction < 33.75):
            return 2
        case _ if (normalized_direction >= 33.75 and normalized_direction < 56.25):
            return 3
        case _ if (normalized_direction >= 56.25 and normalized_direction < 78.75):
            return 4
        case _ if (normalized_direction >= 78.75 and normalized_direction < 101.25):
            return 5
        case _ if (normalized_direction >= 101.25 and normalized_direction < 123.75):
            return 6
        case _ if (normalized_direction >= 123.75 and normalized_direction < 146.25):
            return 7
        case _ if (normalized_direction >= 146.25 and normalized_direction < 168.75):
            return 8
        case _ if (normalized_direction >= 168.75 and normalized_direction < 191.25):
            return 9
        case _ if (normalized_direction >= 191.25 and normalized_direction < 213.75):
            return 10
        case _ if (normalized_direction >= 213.75 and normalized_direction < 236.25):
            return 11
        case _ if (normalized_direction >= 236.25 and normalized_direction < 258.75):
            return 12
        case _ if (normalized_direction >= 258.75 and normalized_direction < 281.25):
            return 13
        case _ if (normalized_direction >= 281.25 and normalized_direction < 303.75):
            return 14
        case _ if (normalized_direction >= 303.75 and normalized_direction < 326.25):
            return 15
        case _ if (normalized_direction >= 326.25 and normalized_direction < 348.75):
            return 16
        case _:
            return 'Invalid'
        
cardinal_points = {
    1:"N",
    2:"NNE",
    3:"NE",
    4:"ENE",
    5:"E",
    6:"ESE",
    7:"SE",
    8:"SSE",
    9:"S",
    10:"SSW",
    11:"SW",
    12:"WSW",
    13:"W",
    14:"WNW",
    15:"NW",
    16:"NNW"
}

# %%
laps = current_session.laps

weather_df = laps.get_weather_data().replace({pd.NaT:None, np.nan:None}).copy()
if not weather_df.empty:
    #weather_df.loc[:, 'session_id'] = session.session_id
    weather_df['time_'] = pd.to_timedelta(weather_df['Time']).dt.total_seconds()
    weather_df['CardinalPoints'] = weather_df['WindDirection'].apply(get_wind_direction_cat)
    weather_df.drop(columns=["Time", "WindDirection"], inplace=True)
    weather_dicts = weather_df.rename(columns={
        'AirTemp': 'air_temp', 
        'Humidity': 'humidity', 
        'Pressure': 'pressure', 
        'Rainfall': 'rainfall',
        'TrackTemp': 'track_temp', 
        'CardinalPoints': 'wind_direction_id', 
        'WindSpeed': 'wind_speed',
    }).to_dict(orient="records")
    print(weather_dicts)
# Out:
# [{'air_temp': 15.7, 'humidity': 74.0, 'pressure': 1010.2, 'rainfall': False, 'track_temp': 19.2, 'wind_speed': 3.9, 'time_': 4268.207, 'wind_direction_id': 12}, {'air_temp': 15.8, 'humidity': 75.0, 'pressure': 1009.9, 'rainfall': False, 'track_temp': 19.2, 'wind_speed': 3.7, 'time_': 4388.207, 'wind_direction_id': 13}, {'air_temp': 15.8, 'humidity': 76.0, 'pressure': 1009.9, 'rainfall': False, 'track_temp': 19.2, 'wind_speed': 3.0, 'time_': 4568.255, 'wind_direction_id': 13}, {'air_temp': 15.8, 'humidity': 74.0, 'pressure': 1009.8, 'rainfall': True, 'track_temp': 19.0, 'wind_speed': 3.3, 'time_': 4748.272, 'wind_direction_id': 13}, {'air_temp': 15.8, 'humidity': 76.0, 'pressure': 1009.9, 'rainfall': True, 'track_temp': 19.0, 'wind_speed': 3.4, 'time_': 4868.288, 'wind_direction_id': 13}, {'air_temp': 15.8, 'humidity': 75.0, 'pressure': 1010.0, 'rainfall': False, 'track_temp': 19.0, 'wind_speed': 3.9, 'time_': 5048.292, 'wind_direction_id': 13}, {'air_temp': 15.9, 'humidity': 76.0, 'p
# ...

# %%
import pandas as pd
import numpy as np
import datetime
driver_laps = current_session.laps.sort_values('LapStartDate').replace({pd.NaT:None}).copy()
driver_laps_date = driver_laps[['LapStartDate', 'LapNumber']].copy()
driver_laps_date = driver_laps_date[driver_laps_date['LapStartDate'].apply(isinstance,args= [datetime.datetime])]
#test = driver_laps_date
driver_laps_date
# Out:
#                    LapStartDate  LapNumber
# 0    2025-03-16 04:18:22.974000        1.0
# 114  2025-03-16 04:18:22.974000        1.0
# 813  2025-03-16 04:18:22.974000        1.0
# 812  2025-03-16 04:18:22.974000        1.0
# 171  2025-03-16 04:18:22.974000        1.0
# ..                          ...        ...
# 869  2025-03-16 05:59:20.420000       57.0
# 113  2025-03-16 05:59:24.705000       57.0
# 374  2025-03-16 05:59:27.924000       57.0
# 592  2025-03-16 05:59:31.754000       57.0
# 926  2025-03-16 05:59:39.316000       57.0
#
# [924 rows x 2 columns]

# %%
for driver in current_session.drivers:
    driver_laps = current_session.laps.sort_values('LapStartDate').pick_drivers(driver)
    car_data_date = driver_laps.get_car_data().replace({pd.NaT:None}).copy()
    print(car_data_date[car_data_date['Date'] == pd.NaT])
# Out:
# Empty DataFrame
# Columns: [Date, RPM, Speed, nGear, Throttle, Brake, DRS, Source, Time, SessionTime]
# Index: []
# Empty DataFrame
# Columns: [Date, RPM, Speed, nGear, Throttle, Brake, DRS, Source, Time, SessionTime]
# Index: []
# Empty DataFrame
# Columns: [Date, RPM, Speed, nGear, Throttle, Brake, DRS, Source, Time, SessionTime]
# Index: []
# Empty DataFrame
# Columns: [Date, RPM, Speed, nGear, Throttle, Brake, DRS, Source, Time, SessionTime]
# Index: []
# Empty DataFrame
# Columns: [Date, RPM, Speed, nGear, Throttle, Brake, DRS, Source, Time, SessionTime]
# Index: []
# Empty DataFrame
# Columns: [Date, RPM, Speed, nGear, Throttle, Brake, DRS, Source, Time, SessionTime]
# Index: []
# Empty DataFrame
# Columns: [Date, RPM, Speed, nGear, Throttle, Brake, DRS, Source, Time, SessionTime]
# Index: []
# Empty DataFrame
# Columns: [Date, RPM, Speed, nGear, Throttle, Brake, DRS, Source, Time, SessionTime]
# Index: []
# Empty DataFrame
# ...

# %%
driver_laps = current_session.laps.pick_drivers(4)
driver_laps.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
driver_laps = current_session.laps.pick_drivers(16)
driver_laps = driver_laps.sort_values('LapStartDate')
driver_laps_date = driver_laps[['LapStartDate', 'LapNumber']].copy()
driver_car_data = driver_laps.get_car_data().add_track_status().add_distance().add_differential_distance().add_relative_distance().add_driver_ahead()
driver_car_data = driver_car_data.sort_values('Date')
driver_car_data = pd.merge_asof(
    driver_car_data,
    driver_laps_date,
    left_on='Date',
    right_on='LapStartDate',
    direction='backward'
)
driver_car_data.drop(columns=['LapStartDate', 'DriverAhead'], inplace=True)
driver_car_data
# Out:
#                          Date     RPM  Speed  nGear  Throttle  Brake  DRS  \
# 0     2025-03-14 01:31:13.953  4048.0   37.0      1       8.0  False    8
# 1     2025-03-14 01:31:14.153  4420.0   38.0      1       9.0  False    8
# 2     2025-03-14 01:31:14.353  4677.0   40.0      1      12.0  False    8
# 3     2025-03-14 01:31:14.594  4730.0   41.0      1      15.0  False    8
# 4     2025-03-14 01:31:14.834  5317.0   45.0      1      22.0  False    8
# ...                       ...     ...    ...    ...       ...    ...  ...
# 14057 2025-03-14 02:33:45.430  9605.0  121.0      3       0.0   True    8
# 14058 2025-03-14 02:33:45.831  7693.0   86.0      2       0.0   True    8
# 14059 2025-03-14 02:33:46.071  6338.0   75.0      2      22.0   True    8
# 14060 2025-03-14 02:33:46.351  6729.0   77.0      2      82.0  False    8
# 14061 2025-03-14 02:33:46.591  6913.0   79.0      2      82.0  False    8
#
#       Source                   Time            SessionTime TrackStatus  \
# ...

# %%
car_data = driver_laps.get_pos_data()
car_data
# Out:
#                          Date   Status       X       Y     Z Source  \
# 0     2025-03-14 01:31:13.748  OnTrack -1300.0 -1031.0   0.0    pos
# 1     2025-03-14 01:31:13.868  OnTrack -1309.0 -1023.0   0.0    pos
# 2     2025-03-14 01:31:14.048  OnTrack -1322.0 -1010.0   0.0    pos
# 3     2025-03-14 01:31:14.368  OnTrack -1357.0  -976.0   0.0    pos
# 4     2025-03-14 01:31:14.768  OnTrack -1380.0  -953.0   0.0    pos
# ...                       ...      ...     ...     ...   ...    ...
# 14364 2025-03-14 02:33:45.514  OnTrack   949.0 -3202.0  82.0    pos
# 14365 2025-03-14 02:33:45.734  OnTrack   881.0 -3137.0  82.0    pos
# 14366 2025-03-14 02:33:46.214  OnTrack   823.0 -3081.0  82.0    pos
# 14367 2025-03-14 02:33:46.394  OnTrack   751.0 -3012.0  82.0    pos
# 14368 2025-03-14 02:33:46.534  OnTrack   729.0 -2990.0  82.0    pos
#
#                         Time            SessionTime
# 0     0 days 00:00:00.215000 0 days 00:15:45.739000
# ...

# %%
if not driver_laps.empty:
    timedelta_cols = ['LapTime', 'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime', 'LapStartTime']
for col in timedelta_cols:
    driver_laps.loc[:, col +'_s'] = driver_laps[col].apply(lambda x: x.total_seconds() if pd.notna(x) else None)
driver_laps_2 = driver_laps[['Compound', 'LapTime_s', 'LapNumber', 'Stint',
                    'PitOutTime_s', 'PitInTime_s',
                    'Sector1Time_s', 'Sector2Time_s', 'Sector3Time_s',
                    'Sector1SessionTime_s', 'Sector2SessionTime_s', 'Sector3SessionTime_s',
                    'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST',
                    'IsPersonalBest', 'TyreLife', 'LapStartTime_s', 'LapStartDate',
                    'Position', 'TrackStatus', 'Deleted'
                ]].copy()
driver_laps_2['LapStartDate'] = pd.to_datetime(driver_laps_2['LapStartDate'])
driver_laps_2
# Out:
#     Compound  LapTime_s  LapNumber  Stint  PitOutTime_s  PitInTime_s  \
# 56    MEDIUM     99.268        1.0    1.0           NaN          NaN
# 57    MEDIUM     97.713        2.0    1.0           NaN          NaN
# 58    MEDIUM     97.597        3.0    1.0           NaN          NaN
# 59    MEDIUM     97.719        4.0    1.0           NaN          NaN
# 60    MEDIUM     97.917        5.0    1.0           NaN          NaN
# 61    MEDIUM     97.856        6.0    1.0           NaN          NaN
# 62    MEDIUM     98.174        7.0    1.0           NaN          NaN
# 63    MEDIUM     98.287        8.0    1.0           NaN          NaN
# 64    MEDIUM     98.514        9.0    1.0           NaN          NaN
# 65    MEDIUM     98.316       10.0    1.0           NaN          NaN
# 66    MEDIUM     98.118       11.0    1.0           NaN          NaN
# 67    MEDIUM     98.197       12.0    1.0           NaN          NaN
# 68    MEDIUM     98.349       13.0    1.0           NaN          NaN
# ...

# %%
session_id = 1
weather_df = current_session.laps.get_weather_data()
if not weather_df.empty:
    weather_df.loc['session_id'] = session_id
    weather_df['time_'] = weather_df.loc[:,'Time'].total_seconds()
    weather_df.drop(columns=["Time"], inplace=True)
    weather_dicts = weather_df.to_dict(orient="records")
weather_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9940/2580927733.py in ?()
#       1 session_id = 1
#       2 weather_df = current_session.laps.get_weather_data()
#       3 if not weather_df.empty:
#       4     weather_df.loc['session_id'] = session_id
# ----> 5     weather_df['time_'] = weather_df.loc[:,'Time'].total_seconds()
#       6     weather_df.drop(columns=["Time"], inplace=True)
#       7     weather_dicts = weather_df.to_dict(orient="records")
#       8 weather_df
#
# ~/Documents/f1_analysis/f1_analysis_env/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# ...

# %%
session.results.TeamName.unique()
# Out:
# array(['McLaren', 'Red Bull Racing', 'Mercedes', 'Williams',
#        'Aston Martin', 'Kick Sauber', 'Ferrari', 'Alpine', 'Racing Bulls',
#        'Haas F1 Team'], dtype=object)

# %%
fastf1.get_event(2025, 1)
# Out:
# RoundNumber                                                          1
# Country                                                      Australia
# Location                                                     Melbourne
# OfficialEventName    FORMULA 1 LOUIS VUITTON AUSTRALIAN GRAND PRIX ...
# EventDate                                          2025-03-16 00:00:00
# EventName                                        Australian Grand Prix
# EventFormat                                               conventional
# Session1                                                    Practice 1
# Session1Date                                 2025-03-14 12:30:00+11:00
# Session1DateUtc                                    2025-03-14 01:30:00
# Session2                                                    Practice 2
# Session2Date                                 2025-03-14 16:00:00+11:00
# Session2DateUtc                                    2025-03-14 05:00:00
# ...

# %%
for i in range(1, 6):
    event = fastf1.get_event(2021, 1) 
    print(event.get_session_name(i))
    print(event.get_session_date(i))
# Out:
# Practice 1
# 2021-03-26 14:30:00+03:00
# Practice 2
# 2021-03-26 18:00:00+03:00
# Practice 3
# 2021-03-27 15:00:00+03:00
# Qualifying
# 2021-03-27 18:00:00+03:00
# Race
# 2021-03-28 18:00:00+03:00

# %%
tyre_allocation = {
    1 : [5, 4, 3],
    2 : [4, 3, 2],
    3 : [3, 2, 1],
    4 : [3, 2, 1],
    5 : [5, 4, 3],
    6 : [5, 4, 3],
    7 : [6, 5, 4],
    8 : [6, 5, 4],
    9 : [3, 2, 1],
    10 : [6, 5, 4],
    11 : [5, 4, 3],
    12 : [4, 3, 2],
    13 : [4, 3, 1],
    14 : [5, 4, 3],
}

# %%
#Add data into event_round table
conn.execute(EventRound.insert().prefix_with("OR IGNORE"),{
"round_number" : session.event.RoundNumber,
"country" : session.event.Country,
"location" : session.event.Location,
"event_name" : session.event.EventName,
"event_date" : session.event.EventName,
"event_format" : session.event.EventName,
"event_name" : session.event.EventName,
"soft" : tyre_allocation.get(session.event.RoundNumber)[0],
"medium" : tyre_allocation.get(session.event.RoundNumber)[1],
"hard" : tyre_allocation.get(session.event.RoundNumber)[2],
})

# %%
teams = fastf1.plotting.list_team_names(session)
for team in teams:
    print(team)
    print(fastf1.plotting.get_team_color(team, session))
# Out:
# req            INFO 	Using cached data for driver_info
# Red Bull Racing
# #0600ef
# Alpine
# #ff87bc
# Mercedes
# #27f4d2
# Aston Martin
# #00665f
# Ferrari
# #e80020
# Racing Bulls
# #fcd700
# Williams
# #00a0dd
# Kick Sauber
# #00e700
# Haas F1 Team
# #b6babd
# McLaren
# #ff8000

# %%
team_info = {
    "Ferrari":["Ferrari", "FER", "#e80020"],
    "McLaren":["McLaren", "MCL", "#ff8000"],
    "Red Bull Racing":["Red Bull Racing", "RBR", "#0600ef"],
    "Alpine":["Alpine", "ALP", "#ff87bc"],
    "Mercedes":["Mercedes", "MER", "#27f4d2"],
    "Aston Martin":["Aston Martin", "AMR", "#00665"],
    "Racing Bulls":["Racing Bulls", "RBL", "#fcd700"],
    "Williams":["Williams", "WIL", "#00a0dd"],
    "Kick Sauber":["Sauber", "SAU", "#00e700"],
    "Haas F1 Team":["Haas", "HAA", "#b6babd"],
}

# %%
drivers_info = {
    1: [1, "VER", "Max Verstappen", "#FF6600", "dutch"],
    30: [30, "LAW", "Liam Lawson", "#FFCC01", "new zeland"],
    10: [10, "GAS", "Pierre Gasly", "#08143b", "france"],
    7: [7, "DOO", "Jack Doohan", "#ff0063", "australia"],
    43: [43, "COL", "Franco Colapinto", "#3576ae", "argentin"],
    12: [12, "ANT", "Kimi Antonelli", "#0ad95d", "italia"],
    63: [63, "RUS", "George Russell", "#00a3e3", "britain"],
    14: [14, "ALO", "Fernando Alonso", "#00a4e7", "spain"],
    18: [18, "STR", "Lance Stroll", "#00665e", "canada"],
    16: [16, "LEC", "Charles Leclerc", "#e1022d", "monaco"],
    44: [44, "HAM", "Lewis Hamilton", "#7a25f0", "monaco"],
    22: [22, "TSU", "Yuki Tsunoda", "#fd8b35", "japan"],
    6: [6, "HAD", "Isack Hadjar", "#0023d1", "france"],
    23: [23, "ALB", "Alexander Albon", "#0023d1", "thailand"],
    55: [55, "SAI", "Carlos Sainz", "#da291c", "spain"],
    27: [27, "HUL", "Nico Hulkenberg", "#181c25", "germany"],
    5: [5, "BOR", "Gabriel Bortoleto", "#a5cd39", "brazil"],
    31: [31, "OCO", "Esteban Ocon", "#f10000", "france"],
    87: [87, "BEA", "Ollie Bearman", "#fff200", "britain"],
    4: [4, "NOR", "Lando Norris", "#d2ff00", "britain"],
    81: [81, "PIA", "Oscar Piastri", "#0e1f66", "autralia"],
}

# %%
for driver in session.drivers:
        print(fastf1.plotting.get_team_name_by_driver(drivers_info.get(int(driver))[1], session))
# Out:
# McLaren
# Red Bull Racing
# Mercedes
# Mercedes
# Williams
# Aston Martin
# Kick Sauber
# Ferrari
# McLaren
# Ferrari
# Alpine
# Racing Bulls
# Haas F1 Team
# Haas F1 Team
# Red Bull Racing
# Kick Sauber
# Aston Martin
# Williams
# Alpine
# Racing Bulls

# %%
teams = fastf1.plotting.list_team_names(session)
#Add data into team table
for team in teams:
    conn.execute(Team.insert().prefix_with("OR IGNORE"),{
    "team_name" : team_info.get(team)[0],
    "team_abreviation" : team_info.get(team)[1],
    "team_color" : team_info.get(team)[2],
    })

# %%
#Add data into driver table
for driver in session.drivers:
    conn.execute(Driver.insert().prefix_with("OR IGNORE"),{
    "driver_number": drivers_info.get(int(driver))[0],
    "broadcast_name": drivers_info.get(int(driver))[1],
    "driver_name": drivers_info.get(int(driver))[2],
    "driver_color": drivers_info.get(int(driver))[3],
    "country": drivers_info.get(int(driver))[4],
    })
